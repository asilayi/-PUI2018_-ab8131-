# %%
import pylab as pl
import pandas as pd
import numpy as np

# %pylab inline

import os
import urllib.request as urllib
import json
if os.getenv ('PUI2016') is None:
    print ("Must set env variable PUI2016")
if os.getenv ('PUIDATA') is None:
    print ("Must set env variable PUI2016")
print(os.getenv("PUIDATA"))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /nfshome/ab8131/PUIdata

# %%
url = 'https://s3.amazonaws.com/tripdata/'
datestring = '201808'
fname = url+datestring+'-citibike-tripdata.csv.zip'
urllib.urlretrieve(fname, '201808.zip')
# !unzip 201808.zip
# Out:
# Archive:  201808.zip
# replace 201808-citibike-tripdata.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
df = pd.read_csv('201808-citibike-tripdata.csv')
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           681  2018-08-01 00:00:07.3210  2018-08-01 00:11:28.9920
# 1           625  2018-08-01 00:00:19.7480  2018-08-01 00:10:45.0290
# 2          1319  2018-08-01 00:00:21.1750  2018-08-01 00:22:20.6370
# 3           220  2018-08-01 00:00:26.4700  2018-08-01 00:04:06.8190
# 4           398  2018-08-01 00:00:30.2910  2018-08-01 00:07:09.2810
#
#    start station id       start station name  start station latitude  \
# 0            3162.0       W 78 St & Broadway               40.783400
# 1            3260.0  Mercer St & Bleecker St               40.727064
# 2             403.0           E 2 St & 2 Ave               40.725029
# 3            3637.0  Fulton St & Waverly Ave               40.683239
# 4            3662.0     31 Ave & Steinway St               40.761294
#
#    start station longitude  end station id             end station name  \
# 0               -73.980931          3383.0    Cathedral Pkwy & Broadway
# 1               -73.996621          2012.0              E 27 St & 1 Ave
# 2               -73.990697           285.0           Broadway & E 14 St
# 3               -73.965996           399.0  Lafayette Ave & St James Pl
# 4               -73.916917          3517.0           31 St & Hoyt Ave N
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.804213             -73.966991   27770  Subscriber
# 1             40.739445             -73.976806   25938  Subscriber
# 2             40.734546             -73.990741   28679  Subscriber
# 3             40.688515             -73.964763   28075  Subscriber
# 4             40.771153             -73.917007   25002  Subscriber
#
#    birth year  gender
# 0        1986       1
# 1        1969       1
# 2        1970       1
# 3        1982       1
# 4        1987       1

# %%
# df is the dataframe where the content of the csv file is stored
df['date'] = pd.to_datetime(df['starttime'])
# note that with dataframes I can refer to variables as dictionary keys, 
# i.e. df['starttime'] or as attributes: df.starttime. 
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           681  2018-08-01 00:00:07.3210  2018-08-01 00:11:28.9920
# 1           625  2018-08-01 00:00:19.7480  2018-08-01 00:10:45.0290
# 2          1319  2018-08-01 00:00:21.1750  2018-08-01 00:22:20.6370
# 3           220  2018-08-01 00:00:26.4700  2018-08-01 00:04:06.8190
# 4           398  2018-08-01 00:00:30.2910  2018-08-01 00:07:09.2810
#
#    start station id       start station name  start station latitude  \
# 0            3162.0       W 78 St & Broadway               40.783400
# 1            3260.0  Mercer St & Bleecker St               40.727064
# 2             403.0           E 2 St & 2 Ave               40.725029
# 3            3637.0  Fulton St & Waverly Ave               40.683239
# 4            3662.0     31 Ave & Steinway St               40.761294
#
#    start station longitude  end station id             end station name  \
# 0               -73.980931          3383.0    Cathedral Pkwy & Broadway
# 1               -73.996621          2012.0              E 27 St & 1 Ave
# 2               -73.990697           285.0           Broadway & E 14 St
# 3               -73.965996           399.0  Lafayette Ave & St James Pl
# 4               -73.916917          3517.0           31 St & Hoyt Ave N
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.804213             -73.966991   27770  Subscriber
# 1             40.739445             -73.976806   25938  Subscriber
# 2             40.734546             -73.990741   28679  Subscriber
# 3             40.688515             -73.964763   28075  Subscriber
# 4             40.771153             -73.917007   25002  Subscriber
#
#    birth year  gender                    date
# 0        1986       1 2018-08-01 00:00:07.321
# 1        1969       1 2018-08-01 00:00:19.748
# 2        1970       1 2018-08-01 00:00:21.175
# 3        1982       1 2018-08-01 00:00:26.470
# 4        1987       1 2018-08-01 00:00:30.291

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'date'],
#       dtype='object')

# %%
df['date'] = pd.to_datetime(df['starttime'])

# %%
#pick 7am to 9am and 5pm to 7pm as rush hour
df_7_9 = df[(df['date'].dt.hour >= 7) & (df['date'].dt.hour < 9)]
df_17_19 = df[(df['date'].dt.hour >= 17) & (df['date'].dt.hour < 19)]

# %%
df_7_9.describe()
# Out:
#         tripduration  start station id  start station latitude  \
# count  240643.000000     240643.000000           240643.000000
# mean      786.757670       1696.641959               40.738598
# std      3333.581354       1460.344690                0.032245
# min        61.000000         72.000000               40.655400
# 25%       353.000000        393.000000               40.717571
# 50%       588.000000        520.000000               40.739355
# 75%       991.000000       3293.000000               40.760958
# max    800828.000000       3705.000000               40.814394
#
#        start station longitude  end station id  end station latitude  \
# count            240643.000000   240643.000000         240643.000000
# mean                -73.980044     1492.021015             40.737418
# std                   0.019438     1425.288057              0.028457
# min                 -74.025353       72.000000             40.655400
# 25%                 -73.993012      360.000000             40.717548
# 50%                 -73.981948      499.000000             40.741022
# 75%                 -73.969617     3233.000000             40.756405
# max                 -73.907744     3705.000000             40.814394
#
#        end station longitude         bikeid     birth year         gender  \
# count          240643.000000  240643.000000  240643.000000  240643.000000
# mean              -73.983992   26072.764169    1979.724642       1.222695
# std                 0.018891    6213.243959      11.541610       0.495899
# min               -74.025353   14529.000000    1885.000000       0.000000
# 25%               -73.996674   19855.000000    1971.000000       1.000000
# 50%               -73.986022   27616.000000    1982.000000       1.000000
# 75%               -73.974498   31354.000000    1989.000000       2.000000
# max               -73.907744   34838.000000    2002.000000       2.000000
#
#           start_hour      stop_hour       trip_id
# count  240643.000000  240643.000000  2.406430e+05
# mean        7.636628       7.867788  9.717147e+05
# std         0.480972       0.650257  5.782250e+05
# min         7.000000       1.000000  2.726000e+03
# 25%         7.000000       7.000000  4.474135e+05
# 50%         8.000000       8.000000  9.358650e+05
# 75%         8.000000       8.000000  1.457792e+06
# max         8.000000      23.000000  1.939507e+06

# %%
df_7_9
# Out:
#          tripduration                     starttime  \
# 314967            608 2018-08-06 08:33:10.252666667
# 316050           1150 2018-08-06 08:49:50.630666667
# 382228           1823 2018-08-07 08:50:12.869666667
# 443594            182 2018-08-08 08:06:27.549000000
# 447049            114 2018-08-08 08:36:29.649000000
# 447285           1192 2018-08-08 08:50:44.638333334
# 511311            546 2018-08-09 07:35:50.854333334
# 512438            241 2018-08-09 07:49:01.461666667
# 516374           1492 2018-08-09 08:45:06.041000000
# 519571            239 2018-08-09 08:58:13.241000000
# 582063            642 2018-08-10 07:08:38.049000000
# 582980            812 2018-08-10 07:31:12.697333334
# 584491           1387 2018-08-10 08:04:06.897000000
# 938813            240 2018-08-16 08:56:57.299333334
# 1168545           205 2018-08-20 07:48:32.877666667
# 1168907           335 2018-08-20 07:54:39.087000000
# 1459617           472 2018-08-24 08:14:47.045000000
# 1529068           929 2018-08-25 08:26:50.047333334
# 1530245           656 2018-08-25 09:02:36.337000000
# 1724432           272 2018-08-28 07:49:00.762000000
# 1797649           755 2018-08-29 09:01:28.820666667
# 1859701           822 2018-08-30 08:32:23.459000000
# 1923920           636 2018-08-31 07:55:44.166333334
# 1926506           113 2018-08-31 08:26:52.609333334
# 1927363           290 2018-08-31 08:39:03.428333334
# 1311264          1002 2018-08-22 08:01:15.028333334
# 1317612           221 2018-08-22 08:51:09.424000000
# 1389256          1088 2018-08-23 08:55:38.973666667
# 1464662           491 2018-08-24 09:03:04.051666667
# 1731169           928 2018-08-28 09:00:06.911000000
# ...               ...                           ...
# 1592734          1046 2018-08-26 08:00:36.061666667
# 1662481           596 2018-08-27 08:56:35.112000000
# 1727204          1230 2018-08-28 08:30:15.829000000
# 1730040           356 2018-08-28 08:44:37.307000000
# 1731067           450 2018-08-28 08:54:00.012333334
# 1731968           278 2018-08-28 08:59:45.160666667
# 1790796          1453 2018-08-29 08:01:51.733000000
# 1792953          1055 2018-08-29 08:22:44.018666667
# 1795129           923 2018-08-29 08:42:06.657333334
# 1853916          1328 2018-08-30 07:15:28.611000000
# 1855849           719 2018-08-30 07:44:22.373666667
# 1863522          2806 2018-08-30 09:28:45.024333334
# 1923450           402 2018-08-31 07:44:48.116333334
# 1925317           126 2018-08-31 08:11:37.782333334
# 1927957           855 2018-08-31 08:51:28.130666667
# 1235321           249 2018-08-21 07:27:24.394666667
# 1313302           653 2018-08-22 08:19:52.791000000
# 1385909          1789 2018-08-23 08:34:25.885000000
# 1389374           241 2018-08-23 08:47:14.669000000
# 1464678           404 2018-08-24 09:02:20.972333334
# 1724438          1059 2018-08-28 07:57:49.031000000
# 1795703           246 2018-08-29 08:39:32.967000000
# 1855944           722 2018-08-30 07:45:56.891666667
# 1858560          2457 2018-08-30 08:38:39.508333334
# 1923839           515 2018-08-31 07:52:53.456666667
# 1459164           638 2018-08-24 08:11:21.670000000
# 1657643          1487 2018-08-27 08:18:35.654666667
# 1923179          1389 2018-08-31 07:50:48.916666667
# 1924572           541 2018-08-31 08:05:10.971666667
# 1926932          1100 2018-08-31 08:43:04.177000000
#
#                              stoptime  start station id  \
# 314967  2018-08-06 08:29:47.340333334            3680.0
# 316050  2018-08-06 08:43:27.210333334            3255.0
# 382228  2018-08-07 08:40:05.140333334             459.0
# 443594  2018-08-08 08:05:26.718000000             382.0
# 447049  2018-08-08 08:35:51.603000000             483.0
# 447285  2018-08-08 08:44:06.986666667             237.0
# 511311  2018-08-09 07:32:48.801666667            3156.0
# 512438  2018-08-09 07:47:40.897333334            3150.0
# 516374  2018-08-09 08:36:48.453000000            3372.0
# 519571  2018-08-09 08:56:53.269000000             498.0
# 582063  2018-08-10 07:05:03.918000000            3175.0
# 582980  2018-08-10 07:26:41.762666667             514.0
# 584491  2018-08-10 07:56:24.286000000             468.0
# 938813  2018-08-16 08:55:36.968666667            3544.0
# 1168545 2018-08-20 07:47:24.420333334            3562.0
# 1168907 2018-08-20 07:52:47.391000000            3576.0
# 1459617 2018-08-24 08:12:09.501000000            3386.0
# 1529068 2018-08-25 08:21:40.362666667            3537.0
# 1530245 2018-08-25 08:58:57.513000000             143.0
# 1724432 2018-08-28 07:47:30.056000000            3297.0
# 1797649 2018-08-29 08:57:17.017333334             410.0
# 1859701 2018-08-30 08:27:49.379000000             545.0
# 1923920 2018-08-31 07:52:12.103666667             358.0
# 1926506 2018-08-31 08:26:14.690666667             435.0
# 1927363 2018-08-31 08:37:26.676666667             334.0
# 1311264 2018-08-22 07:55:40.809666667            3324.0
# 1317612 2018-08-22 08:49:55.599000000             143.0
# 1389256 2018-08-23 08:49:36.122333334            3599.0
# 1464662 2018-08-24 09:00:20.246333334             349.0
# 1731169 2018-08-28 08:54:57.480000000            3054.0
# ...                               ...               ...
# 1592734 2018-08-26 07:54:47.327333334            3577.0
# 1662481 2018-08-27 08:53:16.436000000            3498.0
# 1727204 2018-08-28 08:23:25.769000000             248.0
# 1730040 2018-08-28 08:42:38.342000000             533.0
# 1731067 2018-08-28 08:51:29.856666667             517.0
# 1731968 2018-08-28 08:58:12.481333334             498.0
# 1790796 2018-08-29 07:53:47.194000000             174.0
# 1792953 2018-08-29 08:16:52.067333334             513.0
# 1795129 2018-08-29 08:36:58.822666667             486.0
# 1853916 2018-08-30 07:08:05.617000000            3502.0
# 1855849 2018-08-30 07:40:22.501333334            3158.0
# 1863522 2018-08-30 09:13:09.578666667            2023.0
# 1923450 2018-08-31 07:42:33.804666667             327.0
# 1925317 2018-08-31 08:10:55.707666667             249.0
# 1927957 2018-08-31 08:46:43.072333334              79.0
# 1235321 2018-08-21 07:26:01.336333334             387.0
# 1313302 2018-08-22 08:16:15.069000000             445.0
# 1385909 2018-08-23 08:24:29.385000000            3305.0
# 1389374 2018-08-23 08:45:54.190000000             486.0
# 1464678 2018-08-24 09:00:06.159666667             282.0
# 1724438 2018-08-28 07:51:55.780000000            3357.0
# 1795703 2018-08-29 08:38:10.691000000            3351.0
# 1855944 2018-08-30 07:41:56.127333334            3529.0
# 1858560 2018-08-30 08:25:00.302666667            3542.0
# 1923839 2018-08-31 07:50:01.542333334            3300.0
# 1459164 2018-08-24 08:07:48.932000000             332.0
# 1657643 2018-08-27 08:10:19.704333334             514.0
# 1923179 2018-08-31 07:43:05.814333334             261.0
# 1924572 2018-08-31 08:02:10.444333334             472.0
# 1926932 2018-08-31 08:36:57.202000000             454.0
#
#                     start station name  start station latitude  \
# 314967                 E 43 St & 5 Ave               40.754121
# 316050                 8 Ave & W 31 St               40.750585
# 382228                W 20 St & 11 Ave               40.746745
# 443594         University Pl & E 14 St               40.734927
# 447049                 E 12 St & 3 Ave               40.732233
# 447285                 E 11 St & 2 Ave               40.730473
# 511311              E 72 St & York Ave               40.766638
# 512438              E 85 St & York Ave               40.775369
# 516374                 E 74 St & 1 Ave               40.768974
# 519571              Broadway & W 32 St               40.748549
# 582063         W 70 St & Amsterdam Ave               40.777480
# 582980                12 Ave & W 40 St               40.760875
# 584491              Broadway & W 56 St               40.765265
# 938813      Underhill Ave & Pacific St               40.680484
# 1168545     Classon Ave & St Marks Ave               40.676520
# 1168907       Park Pl & Vanderbilt Ave               40.676700
# 1459617              1 Pl & Clinton St               40.680959
# 1529068          Carlton Ave & Dean St               40.680974
# 1530245      Clinton St & Joralemon St               40.692395
# 1724432                   6 St & 7 Ave               40.668663
# 1797649        Suffolk St & Stanton St               40.720664
# 1859701                E 23 St & 1 Ave               40.736502
# 1923920  Christopher St & Greenwich St               40.732916
# 1926506                W 21 St & 6 Ave               40.741740
# 1927363                W 20 St & 7 Ave               40.742388
# 1311264                  3 Ave & 14 St               40.668546
# 1317612      Clinton St & Joralemon St               40.692395
# 1389256     Franklin Ave & Empire Blvd               40.663140
# 1464662        Rivington St & Ridge St               40.718502
# 1731169        Greene Ave & Throop Ave               40.689493
# ...                                ...                     ...
# 1592734                 34 Ave & 21 St               40.762814
# 1662481        Pleasant Ave & E 120 St               40.797477
# 1727204          Laight St & Hudson St               40.721854
# 1730040             Broadway & W 38 St               40.752996
# 1731067          Pershing Square South               40.751581
# 1731968             Broadway & W 32 St               40.748549
# 1790796                E 25 St & 1 Ave               40.738177
# 1792953               W 56 St & 10 Ave               40.768254
# 1795129             Broadway & W 29 St               40.746201
# 1853916       Lexington Ave & E 111 St               40.795412
# 1855849             W 63 St & Broadway               40.771639
# 1863522        E 55 St & Lexington Ave               40.759681
# 1923450       Vesey Pl & River Terrace               40.715338
# 1925317        Harrison St & Hudson St               40.718710
# 1927957       Franklin St & W Broadway               40.719116
# 1235321        Centre St & Chambers St               40.712733
# 1313302             E 10 St & Avenue A               40.727408
# 1385909                E 91 St & 2 Ave               40.781122
# 1389374             Broadway & W 29 St               40.746201
# 1464678             Kent Ave & S 11 St               40.707645
# 1724438       W 106 St & Amsterdam Ave               40.800836
# 1795703               E 102 St & 1 Ave               40.786995
# 1855944           Lenox Ave & W 130 St               40.810792
# 1858560       Amsterdam Ave & W 119 St               40.808625
# 1923839      Prospect Park West & 8 St               40.665147
# 1459164                      Cherry St               40.712199
# 1657643               12 Ave & W 40 St               40.760875
# 1923179           Johnson St & Gold St               40.694749
# 1924572             E 32 St & Park Ave               40.745712
# 1926932                E 51 St & 1 Ave               40.754557
#
#          start station longitude  end station id  \
# 314967                -73.980252          3255.0
# 316050                -73.994685           377.0
# 382228                -74.007756           418.0
# 443594                -73.992005           483.0
# 447049                -73.988900           237.0
# 447285                -73.986724          3443.0
# 511311                -73.953483          3150.0
# 512438                -73.948034          3372.0
# 516374                -73.954823           498.0
# 519571                -73.988084           466.0
# 582063                -73.982886           514.0
# 582980                -74.002777           468.0
# 584491                -73.981923          3664.0
# 938813                -73.964680          3414.0
# 1168545               -73.959608          3576.0
# 1168907               -73.969024          3637.0
# 1459617               -73.999057           143.0
# 1529068               -73.971010           143.0
# 1530245               -73.993379          3429.0
# 1724432               -73.979881          3663.0
# 1797649               -73.985180           383.0
# 1859701               -73.978095          3459.0
# 1923920               -74.007114           435.0
# 1926506               -73.994156           334.0
# 1927363               -73.997262           491.0
# 1311264               -73.993333           143.0
# 1317612               -73.993379           232.0
# 1389256               -73.960569           467.0
# 1464662               -73.983299          3427.0
# 1731169               -73.942061           323.0
# ...                          ...             ...
# 1592734               -73.934286          3129.0
# 1662481               -73.931185          3520.0
# 1727204               -74.007718           533.0
# 1730040               -73.987216           517.0
# 1731067               -73.977910           498.0
# 1731968               -73.988084          3641.0
# 1790796               -73.977387           513.0
# 1792953               -73.988639           486.0
# 1795129               -73.988557            79.0
# 1853916               -73.944123          3158.0
# 1855849               -73.982614          2023.0
# 1863522               -73.970314           315.0
# 1923450               -74.016584           249.0
# 1925317               -74.009001            79.0
# 1927957               -74.006667          3472.0
# 1235321               -74.004607           249.0
# 1313302               -73.981420           491.0
# 1385909               -73.949656           486.0
# 1389374               -73.988557           402.0
# 1464678               -73.968415           539.0
# 1724438               -73.966449          2006.0
# 1795703               -73.941648          3318.0
# 1855944               -73.943068          3542.0
# 1858560               -73.959621           168.0
# 1923839               -73.976376          3419.0
# 1459164               -73.979481           337.0
# 1657643               -74.002777           427.0
# 1923179               -73.983625           472.0
# 1924572               -73.981948           454.0
# 1926932               -73.965930          3312.0
#
#                             end station name  end station latitude   ...     \
# 314967                       8 Ave & W 31 St             40.750585   ...
# 316050                      6 Ave & Canal St             40.722438   ...
# 382228                    Front St & Gold St             40.702240   ...
# 443594                       E 12 St & 3 Ave             40.732233   ...
# 447049                       E 11 St & 2 Ave             40.730473   ...
# 447285                       W 52 St & 6 Ave             40.761330   ...
# 511311                    E 85 St & York Ave             40.775369   ...
# 512438                       E 74 St & 1 Ave             40.768974   ...
# 516374                    Broadway & W 32 St             40.748549   ...
# 519571                       W 25 St & 6 Ave             40.743954   ...
# 582063                      12 Ave & W 40 St             40.760875   ...
# 582980                    Broadway & W 56 St             40.765265   ...
# 584491         North Moore St & Greenwich St             40.720195   ...
# 938813              Bergen St & Flatbush Ave             40.680945   ...
# 1168545             Park Pl & Vanderbilt Ave             40.676700   ...
# 1168907              Fulton St & Waverly Ave             40.683239   ...
# 1459617            Clinton St & Joralemon St             40.692395   ...
# 1529068            Clinton St & Joralemon St             40.692395   ...
# 1530245               Hanson Pl & Ashland Pl             40.685068   ...
# 1724432                  Sterling Pl & 7 Ave             40.677165   ...
# 1797649           Greenwich Ave & Charles St             40.735238   ...
# 1859701                      E 53 St & 3 Ave             40.757632   ...
# 1923920                      W 21 St & 6 Ave             40.741740   ...
# 1926506                      W 20 St & 7 Ave             40.742388   ...
# 1927363                 E 24 St & Park Ave S             40.740964   ...
# 1311264            Clinton St & Joralemon St             40.692395   ...
# 1317612          Cadman Plaza E & Tillary St             40.695977   ...
# 1389256                      Dean St & 4 Ave             40.683125   ...
# 1464662             Lafayette St & Jersey St             40.724305   ...
# 1731169          Lawrence St & Willoughby St             40.692362   ...
# ...                                      ...                   ...   ...
# 1592734     Queens Plaza North & Crescent St             40.751102   ...
# 1662481  Adam Clayton Powell Blvd & W 118 St             40.804372   ...
# 1727204                   Broadway & W 38 St             40.752996   ...
# 1730040                Pershing Square South             40.751581   ...
# 1731067                   Broadway & W 32 St             40.748549   ...
# 1731968                   Broadway & W 25 St             40.742869   ...
# 1790796                     W 56 St & 10 Ave             40.768254   ...
# 1792953                   Broadway & W 29 St             40.746201   ...
# 1795129             Franklin St & W Broadway             40.719116   ...
# 1853916                   W 63 St & Broadway             40.771639   ...
# 1855849              E 55 St & Lexington Ave             40.759681   ...
# 1863522             South St & Gouverneur Ln             40.703554   ...
# 1923450              Harrison St & Hudson St             40.718710   ...
# 1925317             Franklin St & W Broadway             40.719116   ...
# 1927957                     W 15 St & 10 Ave             40.742754   ...
# 1235321              Harrison St & Hudson St             40.718710   ...
# 1313302                 E 24 St & Park Ave S             40.740964   ...
# 1385909                   Broadway & W 29 St             40.746201   ...
# 1389374                   Broadway & E 22 St             40.740343   ...
# 1464678       Metropolitan Ave & Bedford Ave             40.715348   ...
# 1724438               Central Park S & 6 Ave             40.765909   ...
# 1795703                      2 Ave & E 96 St             40.783964   ...
# 1855944             Amsterdam Ave & W 119 St             40.808625   ...
# 1858560                      W 18 St & 6 Ave             40.739713   ...
# 1923839                  Douglass St & 4 Ave             40.679279   ...
# 1459164                  Old Slip & Front St             40.703799   ...
# 1657643                  Bus Slip & State St             40.701907   ...
# 1923179                   E 32 St & Park Ave             40.745712   ...
# 1924572                      E 51 St & 1 Ave             40.754557   ...
# 1926932                      1 Ave & E 94 St             40.781721   ...
#
#          bikeid    usertype birth year  gender                    date  \
# 314967    14529  Subscriber       1987       1 2018-08-06 08:26:24.428
# 316050    14529  Subscriber       1978       1 2018-08-06 08:37:03.790
# 382228    14529  Subscriber       1989       1 2018-08-07 08:29:57.411
# 443594    14529  Subscriber       1988       2 2018-08-08 08:04:25.887
# 447049    14529  Subscriber       1971       1 2018-08-08 08:35:13.557
# 447285    14529  Subscriber       1980       1 2018-08-08 08:37:29.335
# 511311    14529  Subscriber       1968       2 2018-08-09 07:29:46.749
# 512438    14529  Subscriber       1991       1 2018-08-09 07:46:20.333
# 516374    14529  Subscriber       1994       2 2018-08-09 08:28:30.865
# 519571    14529  Subscriber       1985       1 2018-08-09 08:55:33.297
# 582063    14529  Subscriber       1994       1 2018-08-10 07:01:29.787
# 582980    14529  Subscriber       1955       1 2018-08-10 07:22:10.828
# 584491    14529  Subscriber       1973       1 2018-08-10 07:48:41.675
# 938813    14529  Subscriber       1980       1 2018-08-16 08:54:16.638
# 1168545   14529  Subscriber       1965       1 2018-08-20 07:46:15.963
# 1168907   14529  Subscriber       1980       1 2018-08-20 07:50:55.695
# 1459617   14529  Subscriber       1980       2 2018-08-24 08:09:31.957
# 1529068   14529    Customer       1960       2 2018-08-25 08:16:30.678
# 1530245   14529  Subscriber       1985       2 2018-08-25 08:55:18.689
# 1724432   14529  Subscriber       1988       1 2018-08-28 07:45:59.350
# 1797649   14529  Subscriber       1963       1 2018-08-29 08:53:05.214
# 1859701   14529  Subscriber       1960       2 2018-08-30 08:23:15.299
# 1923920   14529  Subscriber       1969       0 2018-08-31 07:48:40.041
# 1926506   14529  Subscriber       1993       2 2018-08-31 08:25:36.772
# 1927363   14529  Subscriber       1978       1 2018-08-31 08:35:49.925
# 1311264   14531  Subscriber       1974       1 2018-08-22 07:50:06.591
# 1317612   14531  Subscriber       1984       1 2018-08-22 08:48:41.774
# 1389256   14531  Subscriber       1973       2 2018-08-23 08:43:33.271
# 1464662   14531  Subscriber       1990       2 2018-08-24 08:57:36.441
# 1731169   14531  Subscriber       1994       1 2018-08-28 08:49:48.049
# ...         ...         ...        ...     ...                     ...
# 1592734   34820  Subscriber       1983       2 2018-08-26 07:48:58.593
# 1662481   34820  Subscriber       1969       0 2018-08-27 08:49:57.760
# 1727204   34820  Subscriber       1990       1 2018-08-28 08:16:35.709
# 1730040   34820  Subscriber       1979       1 2018-08-28 08:40:39.377
# 1731067   34820  Subscriber       1975       1 2018-08-28 08:48:59.701
# 1731968   34820  Subscriber       1989       1 2018-08-28 08:56:39.802
# 1790796   34820  Subscriber       1986       1 2018-08-29 07:45:42.655
# 1792953   34820  Subscriber       1984       1 2018-08-29 08:11:00.116
# 1795129   34820  Subscriber       1991       1 2018-08-29 08:31:50.988
# 1853916   34820    Customer       1964       2 2018-08-30 07:00:42.623
# 1855849   34820  Subscriber       1969       2 2018-08-30 07:36:22.629
# 1863522   34820  Subscriber       1975       0 2018-08-30 08:57:34.133
# 1923450   34820  Subscriber       1965       1 2018-08-31 07:40:19.493
# 1925317   34820  Subscriber       1969       1 2018-08-31 08:10:13.633
# 1927957   34820  Subscriber       1992       1 2018-08-31 08:41:58.014
# 1235321   34821  Subscriber       1973       1 2018-08-21 07:24:38.278
# 1313302   34821  Subscriber       1993       1 2018-08-22 08:12:37.347
# 1385909   34821  Subscriber       1991       1 2018-08-23 08:14:32.885
# 1389374   34821  Subscriber       1974       1 2018-08-23 08:44:33.711
# 1464678   34821  Subscriber       1985       2 2018-08-24 08:57:51.347
# 1724438   34821  Subscriber       1965       1 2018-08-28 07:46:02.529
# 1795703   34821  Subscriber       1993       1 2018-08-29 08:36:48.415
# 1855944   34821  Subscriber       1981       1 2018-08-30 07:37:55.363
# 1858560   34821  Subscriber       1984       0 2018-08-30 08:11:21.097
# 1923839   34821  Subscriber       1966       1 2018-08-31 07:47:09.628
# 1459164   34835  Subscriber       1953       1 2018-08-24 08:04:16.194
# 1657643   34835  Subscriber       1977       1 2018-08-27 08:02:03.754
# 1923179   34838  Subscriber       1993       1 2018-08-31 07:35:22.712
# 1924572   34838  Subscriber       1991       1 2018-08-31 07:59:09.917
# 1926932   34838  Subscriber       1986       1 2018-08-31 08:30:50.227
#
#         start_hour  stop_hour  start_date  stop_date  trip_id
# 314967           8          8  2018-08-06 2018-08-06   314967
# 316050           8          8  2018-08-06 2018-08-06   316050
# 382228           8          9  2018-08-07 2018-08-07   382228
# 443594           8          8  2018-08-08 2018-08-08   443594
# 447049           8          8  2018-08-08 2018-08-08   447049
# 447285           8          8  2018-08-08 2018-08-08   447285
# 511311           7          7  2018-08-09 2018-08-09   511311
# 512438           7          7  2018-08-09 2018-08-09   512438
# 516374           8          8  2018-08-09 2018-08-09   516374
# 519571           8          8  2018-08-09 2018-08-09   519571
# 582063           7          7  2018-08-10 2018-08-10   582063
# 582980           7          7  2018-08-10 2018-08-10   582980
# 584491           7          8  2018-08-10 2018-08-10   584491
# 938813           8          8  2018-08-16 2018-08-16   938813
# 1168545          7          7  2018-08-20 2018-08-20  1168545
# 1168907          7          7  2018-08-20 2018-08-20  1168907
# 1459617          8          8  2018-08-24 2018-08-24  1459617
# 1529068          8          8  2018-08-25 2018-08-25  1529068
# 1530245          8          9  2018-08-25 2018-08-25  1530245
# 1724432          7          7  2018-08-28 2018-08-28  1724432
# 1797649          8          9  2018-08-29 2018-08-29  1797649
# 1859701          8          8  2018-08-30 2018-08-30  1859701
# 1923920          7          7  2018-08-31 2018-08-31  1923920
# 1926506          8          8  2018-08-31 2018-08-31  1926506
# 1927363          8          8  2018-08-31 2018-08-31  1927363
# 1311264          7          8  2018-08-22 2018-08-22  1311264
# 1317612          8          8  2018-08-22 2018-08-22  1317612
# 1389256          8          9  2018-08-23 2018-08-23  1389256
# 1464662          8          9  2018-08-24 2018-08-24  1464662
# 1731169          8          9  2018-08-28 2018-08-28  1731169
# ...            ...        ...         ...        ...      ...
# 1592734          7          8  2018-08-26 2018-08-26  1592734
# 1662481          8          8  2018-08-27 2018-08-27  1662481
# 1727204          8          8  2018-08-28 2018-08-28  1727204
# 1730040          8          8  2018-08-28 2018-08-28  1730040
# 1731067          8          8  2018-08-28 2018-08-28  1731067
# 1731968          8          9  2018-08-28 2018-08-28  1731968
# 1790796          7          8  2018-08-29 2018-08-29  1790796
# 1792953          8          8  2018-08-29 2018-08-29  1792953
# 1795129          8          8  2018-08-29 2018-08-29  1795129
# 1853916          7          7  2018-08-30 2018-08-30  1853916
# 1855849          7          7  2018-08-30 2018-08-30  1855849
# 1863522          8          9  2018-08-30 2018-08-30  1863522
# 1923450          7          7  2018-08-31 2018-08-31  1923450
# 1925317          8          8  2018-08-31 2018-08-31  1925317
# 1927957          8          8  2018-08-31 2018-08-31  1927957
# 1235321          7          7  2018-08-21 2018-08-21  1235321
# 1313302          8          8  2018-08-22 2018-08-22  1313302
# 1385909          8          8  2018-08-23 2018-08-23  1385909
# 1389374          8          8  2018-08-23 2018-08-23  1389374
# 1464678          8          9  2018-08-24 2018-08-24  1464678
# 1724438          7          8  2018-08-28 2018-08-28  1724438
# 1795703          8          8  2018-08-29 2018-08-29  1795703
# 1855944          7          7  2018-08-30 2018-08-30  1855944
# 1858560          8          8  2018-08-30 2018-08-30  1858560
# 1923839          7          7  2018-08-31 2018-08-31  1923839
# 1459164          8          8  2018-08-24 2018-08-24  1459164
# 1657643          8          8  2018-08-27 2018-08-27  1657643
# 1923179          7          7  2018-08-31 2018-08-31  1923179
# 1924572          7          8  2018-08-31 2018-08-31  1924572
# 1926932          8          8  2018-08-31 2018-08-31  1926932
#
# [240643 rows x 21 columns]

# %%
# dropping NaN values
df_7_9.dropna(inplace = True)
df_17_19.dropna(inplace = True)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
bins = np.arange(60,3000,100)
axD = df_7_9.tripduration.groupby(pd.cut(df_7_9.tripduration, bins)).agg([count_nonzero]).plot(kind='bar', 
                                                                legend=False)
axD2 = df_17_19.tripduration.groupby(pd.cut(df_17_19.tripduration, bins)).agg([count_nonzero]).plot(kind='bar', 
                                                                legend=False)

axD.set_title("7am to 9am tripduration")
axD2.set_title("5pm to 7 pm tripduration")
# Out:
# Text(0.5,1,'5pm to 7 pm tripduration')

# %%
# top 10 starting locations at 7am to 9am 
top_starts = df_7_9.groupby(['start station name', 'start station latitude', 'start station longitude', 'start station id']).count().tripduration.sort_values(ascending = False)
top_starts = top_starts.reset_index()
top_starts['number_trips'] = top_starts.tripduration
top_starts

top_starts.sort_values('number_trips').tail(30).plot(kind = 'barh', 
                         x = 'start station name', y = 'number_trips',figsize=(12,12))
plt.tick_params(labelsize=18)

# %%
# top 10 stopping locations at 7am to 9 am
top_stops = df_7_9.groupby(['end station name', 'end station latitude', 'end station longitude', 'end station id']).count().tripduration.sort_values(ascending = False)
top_stops = top_stops.reset_index()
top_stops['number_trips'] = top_stops.tripduration
top_stops

top_stops.sort_values('number_trips').tail(30).plot(kind = 'barh', 
                         x = 'end station name', y = 'number_trips',figsize=(12,12))
plt.tick_params(labelsize=18)

# %%
# top 10 starting locations at 5pm to 7pm 
top_starts2 = df_17_19.groupby(['start station name', 'start station latitude', 'start station longitude', 'start station id']).count().tripduration.sort_values(ascending = False)
top_starts2 = top_starts.reset_index()
top_starts2['number_trips'] = top_starts2.tripduration
top_starts2

top_starts2.sort_values('number_trips').tail(30).plot(kind = 'barh', 
                         x = 'start station name', y = 'number_trips',figsize=(12,12))
plt.tick_params(labelsize=18)

# %%
# top 10 stopping locations at 5pm to 7 pm
top_stops2 = df_17_19.groupby(['end station name', 'end station latitude', 'end station longitude', 'end station id']).count().tripduration.sort_values(ascending = False)
top_stops2 = top_stops.reset_index()
top_stops2['number_trips'] = top_stops2.tripduration
top_stops2

top_stops2.sort_values('number_trips').tail(30).plot(kind = 'barh', 
                         x = 'end station name', y = 'number_trips',figsize=(12,12))
plt.tick_params(labelsize=18)

# %% [markdown]
# it can be seen that  there is a pattern of behavior where bikes move from residential
# areas to commercial areas at morning peak time and back again over the course of the day at evening peak time.

# %%
def plot_top_stations(df, x_values, y_values):
    pl = df.plot(kind = 'scatter', x = x_values, y = y_values, 
                alpha = 0.5, figsize = (5,8))
    df.head(30).reset_index().plot(kind = 'scatter', x = x_values,
                 color = 'r', y = y_values, ax = pl)

plot_top_stations(top_starts, 'start station longitude', 'start station latitude')
plot_top_stations(top_stops, 'end station longitude', 'end station latitude')
plot_top_stations(top_starts2, 'start station longitude', 'start station latitude')
plot_top_stations(top_stops2, 'end station longitude', 'end station latitude')

# %%
df_7_9['starttime'] = df_7_9['starttime'].apply(pd.to_datetime)
df_7_9['stoptime'] = df_7_9['stoptime'].apply(pd.to_datetime)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_7_9.head()
# Out:
#         tripduration                     starttime  \
# 314967           608 2018-08-06 08:33:10.252666667
# 316050          1150 2018-08-06 08:49:50.630666667
# 382228          1823 2018-08-07 08:50:12.869666667
# 443594           182 2018-08-08 08:06:27.549000000
# 447049           114 2018-08-08 08:36:29.649000000
#
#                             stoptime  start station id  \
# 314967 2018-08-06 08:29:47.340333334            3680.0
# 316050 2018-08-06 08:43:27.210333334            3255.0
# 382228 2018-08-07 08:40:05.140333334             459.0
# 443594 2018-08-08 08:05:26.718000000             382.0
# 447049 2018-08-08 08:35:51.603000000             483.0
#
#              start station name  start station latitude  \
# 314967          E 43 St & 5 Ave               40.754121
# 316050          8 Ave & W 31 St               40.750585
# 382228         W 20 St & 11 Ave               40.746745
# 443594  University Pl & E 14 St               40.734927
# 447049          E 12 St & 3 Ave               40.732233
#
#         start station longitude  end station id    end station name  \
# 314967               -73.980252          3255.0     8 Ave & W 31 St
# 316050               -73.994685           377.0    6 Ave & Canal St
# 382228               -74.007756           418.0  Front St & Gold St
# 443594               -73.992005           483.0     E 12 St & 3 Ave
# 447049               -73.988900           237.0     E 11 St & 2 Ave
#
#         end station latitude   ...    bikeid    usertype birth year  gender  \
# 314967             40.750585   ...     14529  Subscriber       1987       1
# 316050             40.722438   ...     14529  Subscriber       1978       1
# 382228             40.702240   ...     14529  Subscriber       1989       1
# 443594             40.732233   ...     14529  Subscriber       1988       2
# 447049             40.730473   ...     14529  Subscriber       1971       1
#
#                           date start_hour  stop_hour  start_date  stop_date  \
# 314967 2018-08-06 08:26:24.428          8          8  2018-08-06 2018-08-06
# 316050 2018-08-06 08:37:03.790          8          8  2018-08-06 2018-08-06
# 382228 2018-08-07 08:29:57.411          8          9  2018-08-07 2018-08-07
# 443594 2018-08-08 08:04:25.887          8          8  2018-08-08 2018-08-08
# 447049 2018-08-08 08:35:13.557          8          8  2018-08-08 2018-08-08
#
#        trip_id
# 314967  314967
# 316050  316050
# 382228  382228
# 443594  443594
# 447049  447049
#
# [5 rows x 21 columns]

# %%
df_17_19['starttime'] = df_17_19['starttime'].apply(pd.to_datetime)
df_17_19['stoptime'] = df_17_19['stoptime'].apply(pd.to_datetime)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_17_19.head()
# Out:
#         tripduration                     starttime  \
# 286100           831 2018-08-05 17:23:03.043666667
# 288349          1292 2018-08-05 17:56:20.442000000
# 293957          1686 2018-08-05 19:14:13.459000000
# 347540           961 2018-08-06 17:49:56.012000000
# 350203           865 2018-08-06 18:09:19.258000000
#
#                             stoptime  start station id  \
# 286100 2018-08-05 17:18:25.727333334            3467.0
# 288349 2018-08-05 17:49:09.455000000            2008.0
# 293957 2018-08-05 19:04:51.435000000            3435.0
# 347540 2018-08-06 17:44:35.578000000             377.0
# 350203 2018-08-06 18:04:30.791000000             462.0
#
#                 start station name  start station latitude  \
# 286100  W Broadway & Spring Street               40.724947
# 288349       Little West St & 1 Pl               40.705693
# 293957     Grand St & Elizabeth St               40.718822
# 347540            6 Ave & Canal St               40.722438
# 350203            W 22 St & 10 Ave               40.746920
#
#         start station longitude  end station id          end station name  \
# 286100               -74.001659          2008.0     Little West St & 1 Pl
# 288349               -74.016777          3435.0   Grand St & Elizabeth St
# 293957               -73.995960           490.0           8 Ave & W 33 St
# 347540               -74.005664           462.0          W 22 St & 10 Ave
# 350203               -74.004519           265.0  Stanton St & Chrystie St
#
#         end station latitude   ...    bikeid    usertype birth year  gender  \
# 286100             40.705693   ...     14529  Subscriber       1985       1
# 288349             40.718822   ...     14529  Subscriber       1991       1
# 293957             40.751551   ...     14529  Subscriber       1982       2
# 347540             40.746920   ...     14529  Subscriber       1979       1
# 350203             40.722293   ...     14529  Subscriber       1989       1
#
#                           date start_hour  stop_hour  start_date  stop_date  \
# 286100 2018-08-05 17:13:48.411         17         17  2018-08-05 2018-08-05
# 288349 2018-08-05 17:41:58.468         17         18  2018-08-05 2018-08-05
# 293957 2018-08-05 18:55:29.411         18         19  2018-08-05 2018-08-05
# 347540 2018-08-06 17:39:15.144         17         17  2018-08-06 2018-08-06
# 350203 2018-08-06 17:59:42.324         17         18  2018-08-06 2018-08-06
#
#        trip_id
# 286100  286100
# 288349  288349
# 293957  293957
# 347540  347540
# 350203  350203
#
# [5 rows x 21 columns]

# %%
oneday = df_7_9[df_7_9.starttime.dt.day == 1]

# %%
oneday2 = df_17_19[df_17_19.starttime.dt.day == 1]

# %%
bike_list = df_7_9.bikeid.unique()

# collect rebalancing events for the first 100 bikes
df_7_9= df_7_9.sort_values(['bikeid', 'starttime'])
col = ['start station id','end station id', 'starttime', 'stoptime', 'bikeid']
df_7_91 = df_7_9[df_7_9.bikeid.isin(bike_list[:100])]

# track rebalancing events 
shift_col = ['end station id','stoptime', 'end station longitude', 'end station latitude', 'end station name']

def shift_con(bike_df):
    bike_df[shift_col] = bike_df[shift_col].shift(1)
    return bike_df[bike_df["start station id"] != bike_df["end station id"]]

# %%
rebal_df_7_9 = df_7_9.groupby('bikeid').apply(shift_con).dropna()
rebal_df_7_9.index = rebal_df_7_9.index.droplevel('bikeid')

# %%
rebal_times = ((rebal_df_7_9.starttime - rebal_df_7_9.stoptime) / 2) + rebal_df_7_9.stoptime
rebal_spreads = (rebal_df_7_9.starttime - rebal_df_7_9.stoptime) / 2

# %%
df_7_9['start_hour'] = df_7_9.starttime.dt.hour
df_7_9['stop_hour'] = df_7_9.stoptime.dt.hour
df_7_9[['start_date', 'stop_date']] = df_7_9[['starttime', 'stoptime']].apply(lambda x: x.dt.floor('d'))
df_7_9.tail()
# Out:
#          tripduration                     starttime  \
# 1459164           638 2018-08-24 08:11:21.670000000
# 1657643          1487 2018-08-27 08:18:35.654666667
# 1923179          1389 2018-08-31 07:50:48.916666667
# 1924572           541 2018-08-31 08:05:10.971666667
# 1926932          1100 2018-08-31 08:43:04.177000000
#
#                              stoptime  start station id    start station name  \
# 1459164 2018-08-24 08:07:48.932000000             332.0             Cherry St
# 1657643 2018-08-27 08:10:19.704333334             514.0      12 Ave & W 40 St
# 1923179 2018-08-31 07:43:05.814333334             261.0  Johnson St & Gold St
# 1924572 2018-08-31 08:02:10.444333334             472.0    E 32 St & Park Ave
# 1926932 2018-08-31 08:36:57.202000000             454.0       E 51 St & 1 Ave
#
#          start station latitude  start station longitude  end station id  \
# 1459164               40.712199               -73.979481           337.0
# 1657643               40.760875               -74.002777           427.0
# 1923179               40.694749               -73.983625           472.0
# 1924572               40.745712               -73.981948           454.0
# 1926932               40.754557               -73.965930          3312.0
#
#             end station name  end station latitude   ...     bikeid  \
# 1459164  Old Slip & Front St             40.703799   ...      34835
# 1657643  Bus Slip & State St             40.701907   ...      34835
# 1923179   E 32 St & Park Ave             40.745712   ...      34838
# 1924572      E 51 St & 1 Ave             40.754557   ...      34838
# 1926932      1 Ave & E 94 St             40.781721   ...      34838
#
#            usertype birth year  gender                    date start_hour  \
# 1459164  Subscriber       1953       1 2018-08-24 08:04:16.194          8
# 1657643  Subscriber       1977       1 2018-08-27 08:02:03.754          8
# 1923179  Subscriber       1993       1 2018-08-31 07:35:22.712          7
# 1924572  Subscriber       1991       1 2018-08-31 07:59:09.917          8
# 1926932  Subscriber       1986       1 2018-08-31 08:30:50.227          8
#
#          stop_hour  start_date  stop_date  trip_id
# 1459164          8  2018-08-24 2018-08-24  1459164
# 1657643          8  2018-08-27 2018-08-27  1657643
# 1923179          7  2018-08-31 2018-08-31  1923179
# 1924572          8  2018-08-31 2018-08-31  1924572
# 1926932          8  2018-08-31 2018-08-31  1926932
#
# [5 rows x 21 columns]

# %%
def create(df, id_key, date_key, hour_key, fl_key):
    # start is associated with an fl_key = 'fluxs_out',
    # and stop is associated with fl_key = 'fluxs_in'
    use_col = [id_key, date_key, hour_key, 'tripduration']
    fluxs = df.groupby([id_key, date_key, hour_key]).count()
    fluxs = fluxs.reset_index()[use_col]
    col_dict = {'tripduration': fl_key,
                date_key: 'date', hour_key: 'hour',
                id_key: 'id'}
    return fluxs.rename(columns = col_dict)

def transforming(df):
    # calculate approximate pickup and drop-off times for rebalancing trips
    t_start = df.starttime
    t_end = df.stoptime
    time_diff = t_start - t_end

    r_start = t_end + time_diff/3.
    r_end = t_end + time_diff*(2/3.)

    df['starttime'] = r_start
    df['stoptime'] = r_end
    return df.rename(columns = {'start_id':'stop_id', 'stop_id':'start_id'})


def merge_fluxs(df1, df2):
    # concatenate fluxes or any other dataset with the keys
    # 'id' 'date' and 'hour
    return pd.merge(df1, df2, how='outer',
                              on = ['id', 'date', 'hour']).fillna(0)

# %%
# create fluxes from normal trips and merge
bikes_out = create(df_7_9, 'start station id', 'start_date','start_hour', 'bikes_out')
bikes_in = create(df_7_9, 'end station id', 'stop_date','stop_hour', 'bikes_in')

merged = merge_fluxs(bikes_out, bikes_in)

# %%
merged.head()
# Out:
#      id       date  hour  bikes_out  bikes_in
# 0  72.0 2018-08-01   7.0        8.0       2.0
# 1  72.0 2018-08-01   8.0       21.0       9.0
# 2  72.0 2018-08-01   9.0        1.0       0.0
# 3  72.0 2018-08-02   7.0        9.0       2.0
# 4  72.0 2018-08-02   8.0        7.0       9.0

# %%
df_7_9['trip_id'] = df_7_9.index.values

# %%
def transforming(df):
    # calculate approximate pickup and drop-off times for rebalancing trips
    t_start = df.starttime
    t_end = df.stoptime
    time_diff = t_start - t_end

    r_start = t_end + time_diff/3.
    r_end = t_end + time_diff*(2/3.)
    
    df['starttime'] = r_start
    df['stoptime'] = r_end
    return df.rename(columns = {'start_id':'stop_id', 'stop_id':'start_id'})

# %%
# merge rebal fluxes
rebals = transform_times(df_7_9)
#create fluxes from rebalanced trips
rflux_out = create(rebals, 'start station id', 'start_date', 'start_hour', 'rbikes_out')
rflux_in = create(rebals, 'end station id', 'stop_date', 'stop_hour', 'rbikes_in')

rmerged = merge_flux(rflux_out, rflux_in)
rmerged['rebal_net_flux'] = rmerged.rbikes_in - rmerged.rbikes_out
rmerged = rmerged.drop(['rbikes_in', 'rbikes_out'], axis=1)

# %%
rmerged.head()
# Out:
#      id       date  hour  rebal_net_flux
# 0  72.0 2018-08-01   7.0            -6.0
# 1  72.0 2018-08-01   8.0           -12.0
# 2  72.0 2018-08-01   9.0            -1.0
# 3  72.0 2018-08-02   7.0            -7.0
# 4  72.0 2018-08-02   8.0             2.0

# %%
merged.head()
# Out:
#      id       date  hour  bikes_out  bikes_in
# 0  72.0 2018-08-01   7.0        8.0       2.0
# 1  72.0 2018-08-01   8.0       21.0       9.0
# 2  72.0 2018-08-01   9.0        1.0       0.0
# 3  72.0 2018-08-02   7.0        9.0       2.0
# 4  72.0 2018-08-02   8.0        7.0       9.0

# %%
rebalance = merge_flux(merged, rmerged)
frebalance
# Out:
#            id       date  hour  bikes_out  bikes_in  rebal_net_flux
# 0        72.0 2018-08-01   7.0        8.0       2.0            -6.0
# 1        72.0 2018-08-01   8.0       21.0       9.0           -12.0
# 2        72.0 2018-08-01   9.0        1.0       0.0            -1.0
# 3        72.0 2018-08-02   7.0        9.0       2.0            -7.0
# 4        72.0 2018-08-02   8.0        7.0       9.0             2.0
# 5        72.0 2018-08-02   9.0        1.0       1.0             0.0
# 6        72.0 2018-08-03   7.0        2.0       3.0             1.0
# 7        72.0 2018-08-03   8.0       17.0       9.0            -8.0
# 8        72.0 2018-08-03   9.0        4.0       0.0            -4.0
# 9        72.0 2018-08-04   7.0        4.0       1.0            -3.0
# 10       72.0 2018-08-04   8.0        6.0       2.0            -4.0
# 11       72.0 2018-08-05   7.0        1.0       0.0            -1.0
# 12       72.0 2018-08-05   8.0        3.0       5.0             2.0
# 13       72.0 2018-08-06   7.0       11.0       6.0            -5.0
# 14       72.0 2018-08-06   8.0       37.0      10.0           -27.0
# 15       72.0 2018-08-06   9.0        4.0       0.0            -4.0
# 16       72.0 2018-08-07   7.0        8.0       5.0            -3.0
# 17       72.0 2018-08-07   8.0       17.0       9.0            -8.0
# 18       72.0 2018-08-07   9.0        2.0       0.0            -2.0
# 19       72.0 2018-08-08   7.0        5.0       6.0             1.0
# 20       72.0 2018-08-08   8.0       11.0      13.0             2.0
# 21       72.0 2018-08-08   9.0        1.0       2.0             1.0
# 22       72.0 2018-08-09   7.0       11.0       5.0            -6.0
# 23       72.0 2018-08-09   8.0       18.0       8.0           -10.0
# 24       72.0 2018-08-10   7.0       14.0       4.0           -10.0
# 25       72.0 2018-08-10   8.0        8.0      14.0             6.0
# 26       72.0 2018-08-10   9.0        3.0       0.0            -3.0
# 27       72.0 2018-08-11   7.0        2.0       2.0             0.0
# 28       72.0 2018-08-12   7.0        4.0       1.0            -3.0
# 29       72.0 2018-08-12   8.0        6.0       4.0            -2.0
# ...       ...        ...   ...        ...       ...             ...
# 52786  3693.0 2018-08-24   8.0        0.0       2.0             2.0
# 52787  3693.0 2018-08-30   7.0        0.0       1.0             1.0
# 52788  3693.0 2018-08-31   9.0        0.0       1.0             1.0
# 52789  3695.0 2018-08-03   9.0        0.0       1.0             1.0
# 52790  3695.0 2018-08-12   8.0        0.0       1.0             1.0
# 52791  3695.0 2018-08-21   9.0        0.0       5.0             5.0
# 52792  3697.0 2018-08-04   7.0        0.0       1.0             1.0
# 52793  3697.0 2018-08-04   9.0        0.0       1.0             1.0
# 52794  3697.0 2018-08-06   9.0        0.0       2.0             2.0
# 52795  3697.0 2018-08-20   9.0        0.0       1.0             1.0
# 52796  3699.0 2018-08-12   7.0        0.0       1.0             1.0
# 52797  3699.0 2018-08-12   8.0        0.0       2.0             2.0
# 52798  3699.0 2018-08-14   7.0        0.0       1.0             1.0
# 52799  3699.0 2018-08-15   8.0        0.0       1.0             1.0
# 52800  3699.0 2018-08-16   7.0        0.0       1.0             1.0
# 52801  3699.0 2018-08-20   7.0        0.0       1.0             1.0
# 52802  3699.0 2018-08-26   7.0        0.0       1.0             1.0
# 52803  3700.0 2018-08-10   8.0        0.0       2.0             2.0
# 52804  3700.0 2018-08-11   7.0        0.0       1.0             1.0
# 52805  3700.0 2018-08-18   9.0        0.0       2.0             2.0
# 52806  3700.0 2018-08-26   8.0        0.0       4.0             4.0
# 52807  3700.0 2018-08-27   7.0        0.0       1.0             1.0
# 52808  3700.0 2018-08-28   7.0        0.0       2.0             2.0
# 52809  3701.0 2018-08-22   9.0        0.0       1.0             1.0
# 52810  3701.0 2018-08-24   9.0        0.0       2.0             2.0
# 52811  3701.0 2018-08-26   7.0        0.0       1.0             1.0
# 52812  3701.0 2018-08-31   9.0        0.0       1.0             1.0
# 52813  3705.0 2018-08-25   8.0        0.0       1.0             1.0
# 52814  3705.0 2018-08-26   7.0        0.0       1.0             1.0
# 52815  3705.0 2018-08-31   8.0        0.0       2.0             2.0
#
# [52816 rows x 6 columns]

# %% [markdown]
# according to the number of bikes out and bikes in, we can predict the net number of bikes which need to be rebalanced.
# In this way we can make the rebalancing work of Citibike company more efficient and make NYC commuters life more convenient in peak hours.
